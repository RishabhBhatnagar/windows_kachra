# %%
import pandas as pd

# %%
df = pd.read_csv('C:\Users\Vincy\Desktop\IRIS\iris.csv')

# %%
import matplotlib.pyplot as plt

# %%
fig = plt.figure()

# %%
ax1 = fig.add_subplot(2,3,1)

# %%
ax1.scatter(df['sepal_length'],df['sepal_width'])

# %%
ax2 = fig.add_subplot(2,3,2)
ax2.scatter(df['sepal_length'],df['petal_length'])

# %%
ax3 = fig.add_subplot(2,3,3)
ax3.scatter(df['sepal_length'],df['petal_width'])

# %%
ax4 = fig.add_subplot(2,3,4)
ax4.scatter(df['sepal_width'],df['petal_width'])

# %%
ax5 = fig.add_subplot(2,3,5)
ax5.scatter(df['sepal_length'],df['petal_width'])

# %%
ax6 = fig.add_subplot(2,3,6)
ax6.scatter(df['petal_length'],df['petal_width'])

# %%
plt.show()

# %%
import seaborn as sns
sns.set()

# %%
data = pd.read_csv('iris1.csv')

# %%
x=sns.pairplot(data, hue='species', size=2.5)

# %%
plt.show(x)
